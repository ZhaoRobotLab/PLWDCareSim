# %%
from SimManager import SimManager

newSimManager = SimManager()
newSimManager.doPass("pass1")
for i in range(5):
    newSimManager.doOneStep()
# Out:
# Interventionist did a step.
# 	(verbal_utterance="ParticipantName, let's start the grocery shopping task by finding items on a shopping list.", nonverbal_behavior=[smile], ready_to_continue=false, current_step=0, final_step=false)
#
#
# Patient did a step.
# 	(forgetfulness_status=yes,
# frustration_status=no,
# anger_status=no,
# engagement_status=yes,
# verbal_utterance="Alright, we need, um... what was it again?",
# nonverbal_behavior=[furrowed brows, patient appears to be trying to recall, looks around seemingly for clues])
#
#
# Not ready to continue step. ready_to_continue is false
# Interventionist did a step.
# 	(verbal_utterance="Don't worry about remembering, I have the list right here. Let's start by picking up a box of cereal.", nonverbal_behavior=[gentle tone, pointing to the list and then to the cereal], ready_to_continue=false, current_step=1, final_step=false)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 6
#       4 newSimManager.doPass("pass1")
#       5 for i in range(5):
# ----> 6     newSimManager.doOneStep()
#
# File a:\NSDocuments\GitHub\pwd\python_SimulatePwD_ADL\SimManager.py:46, in SimManager.doOneStep(self)
#      44 self.patient.last_message_other_agent = self.interventionist.latest_response
#      45 #Prompt the patient using doRespondOtherAgent
# ---> 46 self.patient.doRespondOtherAgent()
#      47 self.printAndLog("Patient did a step.")
#      48 self.printAndLog(f"\t{self.patient.latest_response}")
#
# File a:\NSDocuments\GitHub\pwd\python_SimulatePwD_ADL\Agent.py:46, in Agent.doRespondOtherAgent(self)
#      44 def doRespondOtherAgent(self):
#      45     # Common implementation for doRespondOtherAgent
# ---> 46     self.latest_response = self.GPTObject.completeFromText(self.last_message_other_agent)
#      47     self.last_message_other_agent = ""
#
# File a:\NSDocuments\GitHub\pwd\python_SimulatePwD_ADL\GPTObject.py:88, in GPTObject.completeFromText(self, text)
#      86 def completeFromText(self, text):
#      87     self.chat.append({"role": "user", "content": text})
# ---> 88     agent = self.client.chat.completions.create(
#      89         model=self.model,
#      90         messages=self.chat,
#      91     )
#      92     reply_content = agent.choices[0].message.content
#      93     # print("GPT prompted with: " + text)
#
# File a:\NSDocuments\GitHub\pwd\python_SimulatePwD_ADL\.venv\lib\site-packages\openai\_utils\_utils.py:303, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     301             msg = f"Missing required argument: {quote(missing[0])}"
#     302     raise TypeError(msg)
# --> 303 return func(*args, **kwargs)
#
# File a:\NSDocuments\GitHub\pwd\python_SimulatePwD_ADL\.venv\lib\site-packages\openai\resources\chat\completions.py:604, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     557 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     558 def create(
#     559     self,
#    (...)
#     602     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     603 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 604     return self._post(
#     605         "/chat/completions",
#     606         body=maybe_transform(
#     607             {
#     608                 "messages": messages,
#     609                 "model": model,
#     610                 "frequency_penalty": frequency_penalty,
#     611                 "function_call": function_call,
#     612                 "functions": functions,
#     613                 "logit_bias": logit_bias,
#     614                 "max_tokens": max_tokens,
#     615                 "n": n,
#     616                 "presence_penalty": presence_penalty,
#     617                 "response_format": response_format,
#     618                 "seed": seed,
#     619                 "stop": stop,
#     620                 "stream": stream,
#     621                 "temperature": temperature,
#     622                 "tool_choice": tool_choice,
#     623                 "tools": tools,
#     624                 "top_p": top_p,
#     625                 "user": user,
#     626             },
#     627             completion_create_params.CompletionCreateParams,
#     628         ),
#     629         options=make_request_options(
#     630             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     631         ),
#     632         cast_to=ChatCompletion,
#     633         stream=stream or False,
#     634         stream_cls=Stream[ChatCompletionChunk],
#     635     )
#
# File a:\NSDocuments\GitHub\pwd\python_SimulatePwD_ADL\.venv\lib\site-packages\openai\_base_client.py:1088, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1074 def post(
#    1075     self,
#    1076     path: str,
#    (...)
#    1083     stream_cls: type[_StreamT] | None = None,
#    1084 ) -> ResponseT | _StreamT:
#    1085     opts = FinalRequestOptions.construct(
#    1086         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1087     )
# -> 1088     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File a:\NSDocuments\GitHub\pwd\python_SimulatePwD_ADL\.venv\lib\site-packages\openai\_base_client.py:853, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     844 def request(
#     845     self,
#     846     cast_to: Type[ResponseT],
#    (...)
#     851     stream_cls: type[_StreamT] | None = None,
#     852 ) -> ResponseT | _StreamT:
# --> 853     return self._request(
#     854         cast_to=cast_to,
#     855         options=options,
#     856         stream=stream,
#     857         stream_cls=stream_cls,
#     858         remaining_retries=remaining_retries,
#     859     )
#
# File a:\NSDocuments\GitHub\pwd\python_SimulatePwD_ADL\.venv\lib\site-packages\openai\_base_client.py:877, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     874 self._prepare_request(request)
#     876 try:
# --> 877     response = self._client.send(
#     878         request,
#     879         auth=self.custom_auth,
#     880         stream=stream or self._should_stream_response_body(request=request),
#     881     )
#     882 except httpx.TimeoutException as err:
#     883     if retries > 0:
#
# File a:\NSDocuments\GitHub\pwd\python_SimulatePwD_ADL\.venv\lib\site-packages\httpx\_client.py:901, in Client.send(self, request, stream, auth, follow_redirects)
#     893 follow_redirects = (
#     894     self.follow_redirects
#     895     if isinstance(follow_redirects, UseClientDefault)
#     896     else follow_redirects
#     897 )
#     899 auth = self._build_request_auth(request, auth)
# --> 901 response = self._send_handling_auth(
#     902     request,
#     903     auth=auth,
#     904     follow_redirects=follow_redirects,
#     905     history=[],
#     906 )
#     907 try:
#     908     if not stream:
#
# File a:\NSDocuments\GitHub\pwd\python_SimulatePwD_ADL\.venv\lib\site-packages\httpx\_client.py:929, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     926 request = next(auth_flow)
#     928 while True:
# --> 929     response = self._send_handling_redirects(
#     930         request,
#     931         follow_redirects=follow_redirects,
#     932         history=history,
#     933     )
#     934     try:
#     935         try:
#
# File a:\NSDocuments\GitHub\pwd\python_SimulatePwD_ADL\.venv\lib\site-packages\httpx\_client.py:966, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     963 for hook in self._event_hooks["request"]:
#     964     hook(request)
# --> 966 response = self._send_single_request(request)
#     967 try:
#     968     for hook in self._event_hooks["response"]:
#
# File a:\NSDocuments\GitHub\pwd\python_SimulatePwD_ADL\.venv\lib\site-packages\httpx\_client.py:1002, in Client._send_single_request(self, request)
#     997     raise RuntimeError(
#     998         "Attempted to send an async request with a sync Client instance."
#     999     )
#    1001 with request_context(request=request):
# -> 1002     response = transport.handle_request(request)
#    1004 assert isinstance(response.stream, SyncByteStream)
#    1006 response.request = request
#
# File a:\NSDocuments\GitHub\pwd\python_SimulatePwD_ADL\.venv\lib\site-packages\httpx\_transports\default.py:228, in HTTPTransport.handle_request(self, request)
#     215 req = httpcore.Request(
#     216     method=request.method,
#     217     url=httpcore.URL(
#    (...)
#     225     extensions=request.extensions,
#     226 )
#     227 with map_httpcore_exceptions():
# --> 228     resp = self._pool.handle_request(req)
#     230 assert isinstance(resp.stream, typing.Iterable)
#     232 return Response(
#     233     status_code=resp.status,
#     234     headers=resp.headers,
#     235     stream=ResponseStream(resp.stream),
#     236     extensions=resp.extensions,
#     237 )
#
# File a:\NSDocuments\GitHub\pwd\python_SimulatePwD_ADL\.venv\lib\site-packages\httpcore\_sync\connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     266     with ShieldCancellation():
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#     270     break
#
# File a:\NSDocuments\GitHub\pwd\python_SimulatePwD_ADL\.venv\lib\site-packages\httpcore\_sync\connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     248         raise exc
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#     260     with self._pool_lock:
#     261         # Maintain our position in the request queue, but reset the
#     262         # status so that the request becomes queued again.
#
# File a:\NSDocuments\GitHub\pwd\python_SimulatePwD_ADL\.venv\lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     elif not self._connection.is_available():
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File a:\NSDocuments\GitHub\pwd\python_SimulatePwD_ADL\.venv\lib\site-packages\httpcore\_sync\http11.py:133, in HTTP11Connection.handle_request(self, request)
#     131     with Trace("response_closed", logger, request) as trace:
#     132         self._response_closed()
# --> 133 raise exc
#
# File a:\NSDocuments\GitHub\pwd\python_SimulatePwD_ADL\.venv\lib\site-packages\httpcore\_sync\http11.py:111, in HTTP11Connection.handle_request(self, request)
#     101     pass
#     103 with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#     119 return Response(
#     120     status=status,
#     121     headers=headers,
#    (...)
#     127     },
#     128 )
#
# File a:\NSDocuments\GitHub\pwd\python_SimulatePwD_ADL\.venv\lib\site-packages\httpcore\_sync\http11.py:176, in HTTP11Connection._receive_response_headers(self, request)
#     173 timeout = timeouts.get("read", None)
#     175 while True:
# --> 176     event = self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#     178         break
#
# File a:\NSDocuments\GitHub\pwd\python_SimulatePwD_ADL\.venv\lib\site-packages\httpcore\_sync\http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     209     event = self._h11_state.next_event()
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#     224     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File a:\NSDocuments\GitHub\pwd\python_SimulatePwD_ADL\.venv\lib\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1259, in SSLSocket.recv(self, buflen, flags)
#    1255     if flags != 0:
#    1256         raise ValueError(
#    1257             "non-zero flags not allowed in calls to recv() on %s" %
#    1258             self.__class__)
# -> 1259     return self.read(buflen)
#    1260 else:
#    1261     return super().recv(buflen, flags)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1132, in SSLSocket.read(self, len, buffer)
#    1130         return self._sslobj.read(len, buffer)
#    1131     else:
# -> 1132         return self._sslobj.read(len)
#    1133 except SSLError as x:
#    1134     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
